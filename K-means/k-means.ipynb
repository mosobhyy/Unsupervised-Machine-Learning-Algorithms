# %% [markdown]
# # Import Libararies

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from clustering import k_means

# %% [markdown]
# # Specific data

# %%
data = np.array([[1, 1],
              [2, 1],
              [4, 3],
              [5, 4]])

# %%
_ = plt.scatter(data[:,0], data[:,1])

# %% [markdown]
# ### Test multiple k values

# %%
distortions = []
for k in range(1, 5):
    model = k_means(k)
    model.fit(data)
    distortions.append(model.distortion_)
    sns.scatterplot(x=data[:,0], y=data[:,1], hue=model.labels_)
    sns.scatterplot(x=model.cluster_centers_[:,0], y=model.cluster_centers_[:,1], style=True, markers="+", legend=False)
    plt.title(f'K: {k}')
    plt.show()

# %% [markdown]
# ### Elbow

# %%
plt.plot(distortions)
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.grid()

# %% [markdown]
# # Random data

# %%
n = 100
xy_min = [0, 0]
xy_max = [10, 20]
data = np.random.uniform(low=xy_min, high=xy_max, size=(n,2))
print(data.shape)
# Out:
# (100, 2)

# %%
_ = plt.scatter(data[:,0], data[:,1])

# %% [markdown]
# ### Test multiple k values

# %%
distortions = []
for k in range(1, 11):
    model = k_means(k)
    model.fit(data)
    distortions.append(model.distortion_)
    sns.scatterplot(x=data[:,0], y=data[:,1], hue=model.labels_).legend(loc='upper right')
    sns.scatterplot(x=model.cluster_centers_[:,0], y=model.cluster_centers_[:,1], style=True, markers="+", legend=False)
    plt.title(f'K: {k}')
    plt.show()

# %% [markdown]
# ### Elbow

# %%
plt.plot(distortions)
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.grid()
